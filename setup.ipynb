# %%
import pandas as pd
import numpy as np
import spacy

# %% [markdown]
# ## Setup

# %%
ingredients_df = pd.read_csv("ingredientsList.csv")

# %%
ingredients_df
# Out:
#                              name scientific_name  \
# 0    Alpha-Glucan Oligosaccharide             NaN
# 1                       Aloe Vera             NaN
# 2                       Allantoin             NaN
# 3                           Algin             NaN
# 4                   Algae Extract             NaN
# ..                            ...             ...
# 243                  Zinc Sulfate             NaN
# 244                      Zinc PCA             NaN
# 245                Neoglucosamine             NaN
# 246                       Taurine             NaN
# 247     Sodium Ascorbyl Phosphate             NaN
#
#                                      short_description  \
# 0    Alpha-glucan oligosaccharide is in a class of ...
# 1    Aloe vera, also appear on ingredients lists as...
# 2    Allantoin occurs naturally in the body, but ca...
# 3    Algin, also known as sodium alginate, is a lar...
# 4    It is essentially an underwater plant, designe...
# ...

# %% [markdown]
# ### User input
# The primary purpose of this is to have a user write what their skin concerns are, and then have the model identify those concerns. Then find the ingredients that will help with that.
